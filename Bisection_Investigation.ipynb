# %%
import math
import matplotlib.pyplot as plt
import numpy as np

print("This is my prototype of Bisection Investigation")
equation="x^7-3x"


Xl = 0
Xu = 1
Xm = 0
answer = 0
iteration= 1
tolerance = 0.01
temp=0

def f(x):
    return x**7 - 3*x
    
def Y(data):      
    return data**7 - data*3


def X(data):
     return data**7 - data*3


def solution(x,y):
    return X(x)*Y(y)

    
def root_estimate(x, y):
    
    return (x+y)/2
    
x_values = np.linspace(-10, 10, 1000)

# Calculate corresponding y values using the function
y_values = f(x_values)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label=r"$f(x) = x^7 - 3x$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Plot of f(x) = x^7 - 3x")
plt.grid(True)
plt.legend()
plt.show()

print("The equation Given is: "+str(equation)+"\n\n")
print("My Xl is: " + str(Xl))
print("My Xl is: " + str(Xu))
print("My f(Xl) is: " + str(X(Xl)))
print("My f(Xu) is: " + str(Y(Xu)))
print("The product of Xl and Xu is: " + str(solution(Xl, Xu)) + "\n"+
      "which is less than 0 which means there is at least"+
      "\n"+ "one root on "+str(Xl)+" and "+str(Xu))
answer = solution(Xl, Xu)

if answer <0:
    for x in range(20):
        print("\n")
        print("Iteration " + str(x + 1))
        Xm = root_estimate(Xl, Xu)
        answer = solution(Xl, Xm)
        temp = X(Xm)
        print("My Xl is: " + str(Xl))
        print("My Xu is: " + str(Xu))
        print("My Xm is: " + str(Xm))
        print("My f(Xm) is: " + str(temp))
        if abs(temp)<tolerance:
            break
        if answer < 0:
            print("Product of Xl and Xm is less than 0 " + str(answer))
            Xl = Xl
            Xu = Xm
        elif answer > 0:
            print("Product of Xl and Xm is more than 0 " + str(answer))
            Xl = Xm
            Xu = Xu
        elif answer == 0:
            print("The root is:" + str(Xm))
            break
    print("\n")
    print("The root is: "+str(Xm))

       
            
        
            
elif answer > 0:
    print("hehe")
# Out:
# This is my prototype of Bisection Investigation
# The equation Given is: x^7-3x
#
#
# My Xl is: 0
# My Xl is: 1
# My f(Xl) is: 0
# My f(Xu) is: -2
# The product of Xl and Xu is: 0
# which is less than 0 which means there is at least
# one root on 0 and 1

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

print("This is my prototype of Bisection Investigation")
equation="x^5-sin(x)-0.5"


Xl = 0
Xu = 2
Xm = 0
answer = 0
iteration= 1
tolerance = 0.01
temp=0

def f(x):
    return x**5-np.sin(x)-0.5
    
def Y(data):      
     return data**5-math.sin(data)-0.5


def X(data):
     return data**5-math.sin(data)-0.5


def solution(x,y):
    return X(x)*Y(y)

    
def root_estimate(x, y):
    
    return (x+y)/2
    
x_values = np.linspace(-10, 10, 1000)


# Calculate corresponding y values using the function
y_values = f(x_values)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label=r"$f(x) = x^5 - sin(x) - 0.5$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Plot of f(x) = x^5 - sin(x) - 0.5")
plt.grid(True)
plt.legend()
plt.show()


print("The equation Given is: "+str(equation)+"\n\n")
print("My Xl is: " + str(Xl))
print("My Xl is: " + str(Xu))
print("My f(Xl) is: " + str(X(Xl)))
print("My f(Xu) is: " + str(Y(Xu)))
print("The product of Xl and Xu is: " + str(solution(Xl, Xu)) + "\n"+
      "which is less than 0 which means there is at least"+
      "\n"+ "one root on "+str(Xl)+" and "+str(Xu))
answer = solution(Xl, Xu)

if answer <0:
    for x in range(20):
        print("\n")
        print("Iteration " + str(x + 1))
        Xm = root_estimate(Xl, Xu)
        answer = solution(Xl, Xm)
        temp = X(Xm)
        print("My Xl is: " + str(Xl))
        print("My Xu is: " + str(Xu))
        print("My Xm is: " + str(Xm))
        print("My f(Xm) is: " + str(temp))
        if abs(temp)<tolerance:
            break
        if answer < 0:
            print("Product of Xl and Xm is less than 0 " + str(answer))
            Xl = Xl
            Xu = Xm
        elif answer > 0:
            print("Product of Xl and Xm is more than 0 " + str(answer))
            Xl = Xm
            Xu = Xu
        elif answer == 0:
            print("The root is:" + str(Xm))
            break
    print("\n")
    print("The root is: "+str(Xm))

       
            
        
            
elif answer > 0:
    print("hehe")
# Out:
# This is my prototype of Bisection Investigation
# The equation Given is: x^5-sin(x)-0.5
#
#
# My Xl is: 0
# My Xl is: 2
# My f(Xl) is: -0.5
# My f(Xu) is: 30.59070257317432
# The product of Xl and Xu is: -15.29535128658716
# which is less than 0 which means there is at least
# one root on 0 and 2
#
#
# Iteration 1
# My Xl is: 0
# My Xu is: 2
# My Xm is: 1.0
# My f(Xm) is: -0.3414709848078965
# Product of Xl and Xm is more than 0 0.17073549240394825
#
#
# Iteration 2
# My Xl is: 1.0
# My Xu is: 2
# My Xm is: 1.5
# My f(Xm) is: 6.096255013395946
# Product of Xl and Xm is less than 0 -2.08169420306439
#
#
# Iteration 3
# My Xl is: 1.0
# My Xu is: 1.5
# My Xm is: 1.25
# My f(Xm) is: 1.6027731931444138
# Product of Xl and Xm is less than 0 -0.5473005406867198
#
#
# Iteration 4
# My Xl is: 1.0
# My Xu is: 1.25
# My Xm is: 1.125
# My f(Xm) is: 0.3997648766040298
# Product of Xl and Xm is less than 0 -0.13650810610558528
#
#
# Iteration 5
# My Xl is: 1.0
# My Xu is: 1.125
# My Xm is: 1.0625
# My f(Xm) is: -0.01949378129744228
# Product of Xl and Xm is more than 0 0.00665656069726737
#
#
# Iteration 6
# My Xl is: 1.0625
# My Xu is: 1.125
# My Xm is: 1.09375
# My f(Xm) is: 0.17691885473396174
# Product of Xl and Xm is less than 0 -0.003448817461577811
#
#
# Iteration 7
# My Xl is: 1.0625
# My Xu is: 1.09375
# My Xm is: 1.078125
# My f(Xm) is: 0.07554518632606477
# Product of Xl and Xm is less than 0 -0.0014726613403148337
#
#
# Iteration 8
# My Xl is: 1.0625
# My Xu is: 1.078125
# My Xm is: 1.0703125
# My f(Xm) is: 0.027250545884371036
# Product of Xl and Xm is less than 0 -0.0005312161817058449
#
#
# Iteration 9
# My Xl is: 1.0625
# My Xu is: 1.0703125
# My Xm is: 1.06640625
# My f(Xm) is: 0.0036866521744518543
#
#
# The root is: 1.06640625

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

print("This is my prototype of Bisection Investigation")
equation="e^-(7x)(3.2sin(x) - 0.5cos(x))"


Xl = 0
Xu = 2
Xm = 0
answer = 0
iteration= 1
tolerance = 0.01
temp=0

def f(x):
    return np.exp(-(7*x)) * (3.2*np.sin(x)) - 0.5*np.cos(x)
    
def Y(data):      
     return np.exp(-(7*data)) * (3.2*np.sin(data) - 0.5*np.cos(data))


def X(data):
     return np.exp(-(7*data)) * (3.2*np.sin(data) - 0.5*np.cos(data))


def solution(x,y):
    return X(x)*Y(y)

    
def root_estimate(x, y):
    
    return (x+y)/2
    
x_values = np.linspace(-10, 10, 1000)


# Calculate corresponding y values using the function
y_values = f(x_values)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label=r"$f(x) = e^-(7x)(3.2sin(x) - 0.5cos(x))$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Plot of f(x) = e^-(7x)(3.2sin(x) - 0.5cos(x))")
plt.grid(True)
plt.legend()
plt.show()


print("The equation Given is: "+str(equation)+"\n\n")
print("My Xl is: " + str(Xl))
print("My Xl is: " + str(Xu))
print("My f(Xl) is: " + str(X(Xl)))
print("My f(Xu) is: " + str(Y(Xu)))
print("The product of Xl and Xu is: " + str(solution(Xl, Xu)) + "\n"+
      "which is less than 0 which means there is at least"+
      "\n"+ "one root on "+str(Xl)+" and "+str(Xu))
answer = solution(Xl, Xu)

if answer <0:
    for x in range(20):
        print("\n")
        print("Iteration " + str(x + 1))
        Xm = root_estimate(Xl, Xu)
        answer = solution(Xl, Xm)
        temp = X(Xm)
        print("My Xl is: " + str(Xl))
        print("My Xu is: " + str(Xu))
        print("My Xm is: " + str(Xm))
        print("My f(Xm) is: " + str(temp))
        if abs(temp)<tolerance:
            break
        if answer < 0:
            print("Product of Xl and Xm is less than 0 " + str(answer))
            Xl = Xl
            Xu = Xm
        elif answer > 0:
            print("Product of Xl and Xm is more than 0 " + str(answer))
            Xl = Xm
            Xu = Xu
        elif answer == 0:
            print("The root is:" + str(Xm))
            break
    print("\n")
    print("The root is: "+str(Xm))

       
            
        
            
elif answer > 0:
    print("hehe")
# Out:
# This is my prototype of Bisection Investigation
# The equation Given is: e^-(7x)(3.2sin(x) - 0.5cos(x))
#
#
# My Xl is: 0
# My Xl is: 2
# My f(Xl) is: -0.5
# My f(Xu) is: 2.5925611817366176e-06
# The product of Xl and Xu is: -1.2962805908683088e-06
# which is less than 0 which means there is at least
# one root on 0 and 2
#
#
# Iteration 1
# My Xl is: 0
# My Xu is: 2
# My Xm is: 1.0
# My f(Xm) is: 0.0022090851255335635
#
#
# The root is: 1.0
