# %%
import math

print("This is my prototype of Bisection Investigation")
equation="x^7-3x"

condition_met = False
Xl = 0
Xu = 2
Xm = 0
answer = 0
iteration= 1
tolerance = 0.01
temp=0

def Y(data):      
    return data**5 - math.sin(data) - 0.5


def X(data):
     return data**5 - math.sin(data) - 0.5


def solution(x,y):
    return X(x)*Y(y)

    
def root_estimate(x, y):
    
    return (x+y)/2
    

print("The equation Given is: "+str(equation)+"\n\n")
print("My Xl is: " + str(X(Xl)))
print("My Xu is: " + str(Y(Xu)))
print("The product of Xl and Xu is: " + str(solution(Xl, Xu)) + " which is less than 0 ")
answer = solution(Xl, Xu)

if answer <0:
    for x in range(20):
        print("\n")
        print("Iteration " + str(x + 1))
        Xm = root_estimate(Xl, Xu)
        answer = solution(Xl, Xm)
        temp = X(Xm)
        print("My Xl is: " + str(Xl))
        print("My Xu is: " + str(Xu))
        print("My Xm is: " + str(Xm))
        print("My Xm plugged in the function is: " + str(temp))

        if answer < 0:
            Xl = Xl
            Xu = Xm
        elif answer > 0:
            print("more than 0 " + str(answer))
            Xl = Xm
            Xu = Xu
        elif answer == 0:
            print("The root is equal to Xm " + str(answer))

        # Check if temp is below or equal to 0.01 for the first time
        if temp <= 0.01 and not condition_met:
            print("Stopping the loop because temp is below or equal to 0.01")
            condition_met = True
            break

        # Run one more iteration if condition was met
    if condition_met:
        print("\n Running one more iteration due to condition met.")
        Xm = root_estimate(Xl, Xu)
        answer = solution(Xl, Xm)
        temp = X(Xm)
        print("My Xl is: " + str(Xl))
        print("My Xu is: " + str(Xu))
        print("My Xm is: " + str(Xm))
        print("My Xm plugged in the function is: " + str(temp))
            
        
            
elif answer > 0:
    print("hehe")
    
    
# Initialize a flag to track if the condition has been met
# Out:
# This is my prototype of Bisection Investigation
# The equation Given is: x^7-3x
#
#
# My Xl is: -0.5
# My Xu is: 30.59070257317432
# The product of Xl and Xu is: -15.29535128658716 which is less than 0
#
#
# Iteration 1
# My Xl is: 0
# My Xu is: 2
# My Xm is: 1.0
# My Xm plugged in the function is: -0.3414709848078965
# more than 0 0.17073549240394825
# Stopping the loop because temp is below or equal to 0.01
#
#  Running one more iteration due to condition met.
# My Xl is: 1.0
# My Xu is: 2
# My Xm is: 1.5
# My Xm plugged in the function is: 6.096255013395946
